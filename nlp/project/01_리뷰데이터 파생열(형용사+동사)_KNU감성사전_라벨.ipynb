# %% [markdown]
# ## Import

# %%
# 데이터 분석
import pandas as pd
import numpy as np

# %%
# 시각화
import seaborn as sns
import matplotlib.pyplot as plt
import koreanize_matplotlib

# %%
# 정규표현식
import re

# %%
# 형태소분석 okt
from konlpy.tag import Okt

# %% [markdown]
# ## 파일 불러오기

# %%
df = pd.read_csv('review_data_2t.csv', encoding='utf-8')
df
# Out:
#                                                    review  시설분류
# 0                                                       ?    문화
# 1                                                    친절해요    문화
# 2                                              좋아요 만족스러워요    문화
# 3                                                    와우~~    문화
# 4                                                       굿    문화
# ...                                                   ...   ...
# 141249  설사를해서 병원갔어요 배를 만져보고 꼼꼼히 살펴보시더니 약은 안먹어도 되겠다고 하셔...  동물병원
# 141250  저희 천사 데려온 곳이고 중성화부터 혈액검사까지 전부 세세하게 봐주셔서 늘 감사드립...  동물병원
# 141251                                             친절하십니다  동물병원
# 141252  진료 꼼꼼히 잘봐주세요 진료후 간식도 챙겨주시고 선생님께서 산책 가자고하니 요미가 ...  동물병원
# 141253  선생님들이 너무 친절하셔서 동물병원은 여기만 갑니다  두분 다 좋으시지만 여자원장님...  동물병원
#
# [141254 rows x 2 columns]

# %% [markdown]
# ## 함수

# %% [markdown]
# ### 한글만 추출 함수

# %%
# 한글만 추출 + 2개이상 공백 1개로 변환
def extract_korean(text):
    # 한글만 추출
    text = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣\s]',' ',text)
    # 공백 2개 이상인 경우 1개로 변환
    text = re.sub(r'\s+',' ',text)
    return text

# %% [markdown]
# ### 형용사 + 동사 추출 함수

# %%
# 형용사 추출하기
def get_adjectives(text):
    okt = Okt() # okt 객체 생성
    okt_pos = okt.pos(text)
    join_text = []
    for text, pos in okt_pos:
        if pos == 'Adjective' or pos == 'Verb':
            join_text.append(text)
    return " ".join(join_text)

# %% [markdown]
# ## 한글만 추출 (review2 생성)

# %%
df['review2'] = df['review'].map(lambda review:extract_korean(review))

# %%
df.head(3)
# Out:
#        review 시설분류     review2
# 0           ?   문화
# 1        친절해요   문화        친절해요
# 2  좋아요 만족스러워요   문화  좋아요 만족스러워요

# %% [markdown]
# ## 파생컬럼 생성

# %%
# 시간이 오래 걸리는 작업시 시각적으로 진행상황 수치로( %) 보여준다.
from tqdm import tqdm
tqdm.pandas()

# %%
df['adj_verb'] = df['review'].progress_map(extract_korean).progress_map(get_adjectives)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████| 141254/141254 [00:00<00:00, 186488.97it/s]
# 100%|█████████████████████████████████████████████████████████████████████████| 141254/141254 [04:28<00:00, 526.78it/s]

# %%
df
# Out:
#                                                    review  시설분류  \
# 0                                                       ?    문화
# 1                                                    친절해요    문화
# 2                                              좋아요 만족스러워요    문화
# 3                                                    와우~~    문화
# 4                                                       굿    문화
# ...                                                   ...   ...
# 141249  설사를해서 병원갔어요 배를 만져보고 꼼꼼히 살펴보시더니 약은 안먹어도 되겠다고 하셔...  동물병원
# 141250  저희 천사 데려온 곳이고 중성화부터 혈액검사까지 전부 세세하게 봐주셔서 늘 감사드립...  동물병원
# 141251                                             친절하십니다  동물병원
# 141252  진료 꼼꼼히 잘봐주세요 진료후 간식도 챙겨주시고 선생님께서 산책 가자고하니 요미가 ...  동물병원
# 141253  선생님들이 너무 친절하셔서 동물병원은 여기만 갑니다  두분 다 좋으시지만 여자원장님...  동물병원
#
#                                                   review2  \
# 0
# 1                                                    친절해요
# 2                                              좋아요 만족스러워요
# 3                                                     와우
# 4                                                       굿
# ...                                                   ...
# 141249  설사를해서 병원갔어요 배를 만져보고 꼼꼼히 살펴보시더니 약은 안먹어도 되겠다고 하셔...
# 141250  저희 천사 데려온 곳이고 중성화부터 혈액검사까지 전부 세세하게 봐주셔서 늘 감사드립니다
# 141251                                             친절하십니다
# 141252  진료 꼼꼼히 잘봐주세요 진료후 간식도 챙겨주시고 선생님께서 산책 가자고하니 요미가 ...
# 141253  선생님들이 너무 친절하셔서 동물병원은 여기만 갑니다 두분 다 좋으시지만 여자원장님이...
#
#                                                  adj_verb
# 0
# 1                                                    친절해요
# 2                                              좋아요 만족스러워요
# 3
# 4
# ...                                                   ...
# 141249  해서 갔어요 만져 꼼꼼히 살펴보시더니 먹어도 되겠다고 하셔서 맞고 왔는데 다행히 좋...
# 141250                                 데려온 세세하게 봐주셔서 드립니다
# 141251                                             친절하십니다
# 141252     꼼꼼히 봐주세요 챙겨주시고 가자고하니 따라가네요 해주신 약발라주고 있는데 좋아졌어요
# 141253  친절하셔서 갑니다 좋으시지만 꼼꼼하게 잘 해주셔서 좋더라 말못하는 좋아하는 잘 알잖...
#
# [141254 rows x 4 columns]

# %% [markdown]
# ### 결측치 확인

# %%
df.isnull().sum()
# Out:
# review      0
# 시설분류        0
# review2     0
# adj_verb    0
# dtype: int64

# %% [markdown]
# ### 데이터의 값이 공백인거 NaN으로 변경

# %%
# 데이터값이 공백인거 NaN으로 변경
df_NanTest = df.replace(r'^\s*$', np.nan, regex=True)

# %%
df_NanTest
# Out:
#                                                    review  시설분류  \
# 0                                                       ?    문화
# 1                                                    친절해요    문화
# 2                                              좋아요 만족스러워요    문화
# 3                                                    와우~~    문화
# 4                                                       굿    문화
# ...                                                   ...   ...
# 141249  설사를해서 병원갔어요 배를 만져보고 꼼꼼히 살펴보시더니 약은 안먹어도 되겠다고 하셔...  동물병원
# 141250  저희 천사 데려온 곳이고 중성화부터 혈액검사까지 전부 세세하게 봐주셔서 늘 감사드립...  동물병원
# 141251                                             친절하십니다  동물병원
# 141252  진료 꼼꼼히 잘봐주세요 진료후 간식도 챙겨주시고 선생님께서 산책 가자고하니 요미가 ...  동물병원
# 141253  선생님들이 너무 친절하셔서 동물병원은 여기만 갑니다  두분 다 좋으시지만 여자원장님...  동물병원
#
#                                                   review2  \
# 0                                                     NaN
# 1                                                    친절해요
# 2                                              좋아요 만족스러워요
# 3                                                     와우
# 4                                                       굿
# ...                                                   ...
# 141249  설사를해서 병원갔어요 배를 만져보고 꼼꼼히 살펴보시더니 약은 안먹어도 되겠다고 하셔...
# 141250  저희 천사 데려온 곳이고 중성화부터 혈액검사까지 전부 세세하게 봐주셔서 늘 감사드립니다
# 141251                                             친절하십니다
# 141252  진료 꼼꼼히 잘봐주세요 진료후 간식도 챙겨주시고 선생님께서 산책 가자고하니 요미가 ...
# 141253  선생님들이 너무 친절하셔서 동물병원은 여기만 갑니다 두분 다 좋으시지만 여자원장님이...
#
#                                                  adj_verb
# 0                                                     NaN
# 1                                                    친절해요
# 2                                              좋아요 만족스러워요
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 141249  해서 갔어요 만져 꼼꼼히 살펴보시더니 먹어도 되겠다고 하셔서 맞고 왔는데 다행히 좋...
# 141250                                 데려온 세세하게 봐주셔서 드립니다
# 141251                                             친절하십니다
# 141252     꼼꼼히 봐주세요 챙겨주시고 가자고하니 따라가네요 해주신 약발라주고 있는데 좋아졌어요
# 141253  친절하셔서 갑니다 좋으시지만 꼼꼼하게 잘 해주셔서 좋더라 말못하는 좋아하는 잘 알잖...
#
# [141254 rows x 4 columns]

# %%
df_NanTest.isnull().sum()
# Out:
# review          9
# 시설분류            0
# review2      4927
# adj_verb    30868
# dtype: int64

# %% [markdown]
# ### review2(한글만 남긴 리뷰)의 컬럼 데이터가 NaN이면 제거

# %%
df_NanTest.dropna(subset=['review2'], inplace=True)

# %%
df_NanTest.isnull().sum()
# Out:
# review          0
# 시설분류            0
# review2         0
# adj_verb    25941
# dtype: int64

# %%
df_NanTest.dropna(subset=['adj_verb'], inplace=True)

# %%
df_NanTest.isnull().sum()
# Out:
# review      0
# 시설분류        0
# review2     0
# adj_verb    0
# dtype: int64

# %%
df_NanTest.shape
# Out:
# (110386, 4)

# %% [markdown]
# ## 저장

# %%
df_NanTest.to_csv('data/review_adj_verb.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# ## 감성사전으로 라벨링 작업

# %% [markdown]
# ### 데이터프레임 불러오기

# %%
df_review_data = pd.read_csv('data/review_adj_verb.csv', encoding='utf-8')

# %%
df_review_data.head(20)
# Out:
#                                                review 시설분류  \
# 0                                                친절해요   문화
# 1                                          좋아요 만족스러워요   문화
# 2                                                 좋아요   문화
# 3                                                 좋아요   문화
# 4                  휴일날 찾아간 각화제~\n가을을 부르는 꽃이 피어있네요 ㅋㅋ    문화
# 5                                            산책하기 좋아요   문화
# 6          처음 가봤는데 산책로가 잘 되어있네요~\n한적하게 산책하며 힐링하기 좋습니다   문화
# 7   보현사에서 시작~구릉산~갈매구릉산자락길~모다아울렛구리.갈매역까지 걷기\n\n갈매역 ...   문화
# 8                                                좋습니다   문화
# 9                                                 좋아요   문화
# 10                                                좋아요   문화
# 11  포근한 봄날씨에 강아지와 강아지 숲에서  즐거운 시간을 보내고 왔어요🌸 봄바람 살랑...   문화
# 12  산책+오프리쉬 놀이터 위주라면 봄, 가을 수영장 위주라면 여름 추천합니다! 공간이 ...   문화
# 13  강아지 성지가 될 최고의 장소 - 우연하게 찾아서 예약하고 갔는데 한국 사는 강아지...   문화
# 14  국제강아지의날을 맞이해서 반려견 다찌와 함께 다녀왔어요! 중소형견과 대형견를 위한 ...   문화
# 15  야자매트가 깔려 있는  산책로를  강아지가  너무 좋아해요. 강아지가 길을 따라 냄...   문화
# 16  날씨가 꽤 추울때 방문했는데 강아지들이 꽤 있더라구요. 시설도 깔끔하고 안에 잔디밭...   문화
# 17  입장해서 강아지 운동장,그리고 산책길,마지막은 강아지 박물관도 다녀오느라 거의 3시...   문화
# 18  바람불고 쌀쌀했지만 초코한테는 딱 좋은 날씨라서 먼길 나섰죠 방문객 적어서 전용공간...   문화
# 19  예전부터 정말 가고싶었던 강아지숲! 기대하고 방문했는데, 기대를 너무 많이 했나봐요...   문화
#
#                                               review2  \
# 0                                                친절해요
# 1                                          좋아요 만족스러워요
# 2                                                 좋아요
# 3                                                 좋아요
# 4                    휴일날 찾아간 각화제 가을을 부르는 꽃이 피어있네요 ㅋㅋ
# 5                                            산책하기 좋아요
# 6            처음 가봤는데 산책로가 잘 되어있네요 한적하게 산책하며 힐링하기 좋습니다
# 7   보현사에서 시작 구릉산 갈매구릉산자락길 모다아울렛구리 갈매역까지 걷기 갈매역 근처에...
# 8                                                좋습니다
# 9                                                 좋아요
# 10                                                좋아요
# 11  포근한 봄날씨에 강아지와 강아지 숲에서 즐거운 시간을 보내고 왔어요 봄바람 살랑 부...
# 12  산책 오프리쉬 놀이터 위주라면 봄 가을 수영장 위주라면 여름 추천합니다 공간이 진짜...
# 13  강아지 성지가 될 최고의 장소 우연하게 찾아서 예약하고 갔는데 한국 사는 강아지들이...
# 14  국제강아지의날을 맞이해서 반려견 다찌와 함께 다녀왔어요 중소형견과 대형견를 위한 운...
# 15  야자매트가 깔려 있는 산책로를 강아지가 너무 좋아해요 강아지가 길을 따라 냄새 맡으...
# 16  날씨가 꽤 추울때 방문했는데 강아지들이 꽤 있더라구요 시설도 깔끔하고 안에 잔디밭도...
# 17  입장해서 강아지 운동장 그리고 산책길 마지막은 강아지 박물관도 다녀오느라 거의 시간...
# 18  바람불고 쌀쌀했지만 초코한테는 딱 좋은 날씨라서 먼길 나섰죠 방문객 적어서 전용공간...
# 19  예전부터 정말 가고싶었던 강아지숲 기대하고 방문했는데 기대를 너무 많이 했나봐요ㅋㅋ...
#
#                                              adj_verb
# 0                                                친절해요
# 1                                          좋아요 만족스러워요
# 2                                                 좋아요
# 3                                                 좋아요
# 4                                       찾아간 부르는 피어있네요
# 5                                              하기 좋아요
# 6                        가봤는데 잘 되어있네요 한적하게 하며 하기 좋습니다
# 7                                      있어 하기 좋음 있어 좋음
# 8                                                좋습니다
# 9                                                 좋아요
# 10                                                좋아요
# 11          포근한 즐거운 보내고 왔어요 부는 걷고 먹으며 쉴수 있어서 좋아요 예뻤어요
# 12  합니다 크고 그런지 본 같아요 나눠져 있어서 좋았어요 사악하긴 있네요 쓸 될 같아요...
# 13  될 하게 찾아서 갔는데 사는 어울리기 좋은 입니다 기라 안되지만 충분히 쌓을 있는 ...
# 14  해서 다녀왔어요 있어서 같은 적당하고 좋았어요 맛있고 되어있어서 만족스러웠습니다 와...
# 15  깔려 있는 좋아해요 따라 맡으며 올라가면 사먹으며 마시고 쉴수 있어요 맛있구요 깨끗...
# 16  추울 했는데 있더라구요 깔끔하고 되어있었어요 넓어서 댈 편하고 있어서 하기 편한듯 ...
# 17   해서 다녀오느라 보낸것 같아요 할것도 많고 느껴졌어요 좋을 할 있습니다 좋은 이었습니다
# 18  쌀쌀했지만 는 좋은 먼길 나섰죠 적어서 신나게 놀고 편하게 먹고 좋았어요 더워지기 ...
# 19  가고싶었던 기대하고 했는데 했나 봐요 큰 같다고 왔어요 걸리네요 만들어주셔서 놀랐어...

# %% [markdown]
# ### 정규화, 어간 - 추출 함수

# %%
# # extract_norm 함수 정의
# def extract_norm(words):
#     if pd.isna(words):
#         return words
    
#     okt = Okt()
#     norm = []
#     for word in words:
#         # 정규화
#         norm.append(okt.normalize(word))
#     return norm

# %%
# # extract_stem 함수 정의
# def extract_stem(words):
#     if pd.isna(words):
#         return words
     
#     okt = Okt()
#     stems = []
#     for word in words:
#         # 어간 추출
#         stems.append(okt.morphs(word, stem=True))
#     return stems

# %%
def extract_stemming(words, tokenizer):
    # 문자열을 포함한 다양한 타입에서 NaN 확인
    if pd.isna(words):
        return

    # 전체 텍스트에 대해 한 번에 형태소 분석을 수행
    morphs = tokenizer.morphs(words, stem=True)
    
    # 결과에서 어간만 추출하여 조인
    return ' '.join(morph for morph in morphs if morph)

# %%
from konlpy.tag import Okt
okt = Okt()

# %%
from tqdm import tqdm
tqdm.pandas()
from functools import partial

# %%
# extract_stem 함수에 대한 partial 함수 생성
extract_stem_okt = partial(extract_stemming, tokenizer=okt)

# %%
# df_review_data['adj_verb_normalized'] = df_review_data['adj_verb'].progress_map(extract_norm)

# %%
# df_review_data['adj_verb_stemmed'] = df_review_data['adj_verb'].progress_map(extract_stem)

# %%
df_review_data['adj_verb_stemmed'] = df_review_data['adj_verb'].progress_map(extract_stem_okt)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 110386/110386 [02:03<00:00, 896.58it/s]

# %%
df_review_data
# Out:
#                                                    review  시설분류  \
# 0                                                    친절해요    문화
# 1                                              좋아요 만족스러워요    문화
# 2                                                     좋아요    문화
# 3                                                     좋아요    문화
# 4                      휴일날 찾아간 각화제~\n가을을 부르는 꽃이 피어있네요 ㅋㅋ     문화
# ...                                                   ...   ...
# 110381  설사를해서 병원갔어요 배를 만져보고 꼼꼼히 살펴보시더니 약은 안먹어도 되겠다고 하셔...  동물병원
# 110382  저희 천사 데려온 곳이고 중성화부터 혈액검사까지 전부 세세하게 봐주셔서 늘 감사드립...  동물병원
# 110383                                             친절하십니다  동물병원
# 110384  진료 꼼꼼히 잘봐주세요 진료후 간식도 챙겨주시고 선생님께서 산책 가자고하니 요미가 ...  동물병원
# 110385  선생님들이 너무 친절하셔서 동물병원은 여기만 갑니다  두분 다 좋으시지만 여자원장님...  동물병원
#
#                                                   review2  \
# 0                                                    친절해요
# 1                                              좋아요 만족스러워요
# 2                                                     좋아요
# 3                                                     좋아요
# 4                        휴일날 찾아간 각화제 가을을 부르는 꽃이 피어있네요 ㅋㅋ
# ...                                                   ...
# 110381  설사를해서 병원갔어요 배를 만져보고 꼼꼼히 살펴보시더니 약은 안먹어도 되겠다고 하셔...
# 110382  저희 천사 데려온 곳이고 중성화부터 혈액검사까지 전부 세세하게 봐주셔서 늘 감사드립니다
# 110383                                             친절하십니다
# 110384  진료 꼼꼼히 잘봐주세요 진료후 간식도 챙겨주시고 선생님께서 산책 가자고하니 요미가 ...
# 110385  선생님들이 너무 친절하셔서 동물병원은 여기만 갑니다 두분 다 좋으시지만 여자원장님이...
#
#                                                  adj_verb  \
# 0                                                    친절해요
# 1                                              좋아요 만족스러워요
# 2                                                     좋아요
# 3                                                     좋아요
# 4                                           찾아간 부르는 피어있네요
# ...                                                   ...
# 110381  해서 갔어요 만져 꼼꼼히 살펴보시더니 먹어도 되겠다고 하셔서 맞고 왔는데 다행히 좋...
# 110382                                 데려온 세세하게 봐주셔서 드립니다
# 110383                                             친절하십니다
# 110384     꼼꼼히 봐주세요 챙겨주시고 가자고하니 따라가네요 해주신 약발라주고 있는데 좋아졌어요
# 110385  친절하셔서 갑니다 좋으시지만 꼼꼼하게 잘 해주셔서 좋더라 말못하는 좋아하는 잘 알잖...
#
#                                          adj_verb_stemmed
# 0                                                    친절하다
# 1                                                좋다 만족스럽다
# 2                                                      좋다
# 3                                                      좋다
# 4                                             찾아가다 부르다 피다
# ...                                                   ...
# 110381      하다 가다 만지다 꼼꼼하다 살펴보다 먹다 되다 하다 맞다 오다 다행하다 좋다 지다
# 110382                                     데려오다 세다 보다 드리다
# 110383                                               친절하다
# 110384               꼼꼼하다 보다 챙기다 가다 따라가다 해주다 약바르다 있다 좋아지다
# 110385  친절하다 가다 좋다 꼼꼼하다 자다 해주다 좋다 말다 좋아하다 자다 알다 이쁘다 해주...
#
# [110386 rows x 5 columns]

# %% [markdown]
# ### 감성사전 불러오기

# %%
import json

# %%
with open('data/SentiWord_info.json', encoding='utf-8-sig', mode='r') as f:
    Sentiword_info = json.load(f)

# %%
sentiword_dic = pd.DataFrame(Sentiword_info)

# %%
sentiword_dic
# Out:
#          word word_root polarity
# 0         (-;         (        1
# 1       (;_;)     (;_;)       -1
# 2        (^^)      (^^)        1
# 3       (^-^)     (^-^)        1
# 4        (^^*         (        1
# ...       ...       ...      ...
# 14849  반신반의하다      반신반의        0
# 14850    신비롭다        신비        1
# 14851   아리송하다       아리송       -1
# 14852    알쏭하다       알쏭하       -1
# 14853  알쏭달쏭하다      알쏭달쏭       -1
#
# [14854 rows x 3 columns]

# %% [markdown]
# #### 감성사전 추가하기

# %%
# 추가할 단어 있으면 추가하기
new_row = {'word': '친절해요', 'word_root': '친절', 'polarity' : '2'}
sentiword_dic = pd.concat([sentiword_dic, pd.DataFrame(new_row, index=[0])], ignore_index=True)

# %% [markdown]
# ### 라벨링 작업

# %%
# df = pd.DataFrame(columns=('adj_verb', 'sentiment'))
# idx = 0 # 다음 리뷰로 넘기기 위한 초기값

# for adj_verb in df_review_data['adj_verb']:  # df_review_data의 adj_verb 열의 각 토큰에 대해 루프
#     sentiment = 0  # 초기 감성값 0으로 설정
#     for i in range(len(sentiword_dic)):  # 감성사전의 모든 단어에 대해 루프
#         if sentiword_dic.word_root[i] in adj_verb and sentiword_dic.word[i] in adj_verb:  # 리뷰 문장에 감성 단어가 있는지 확인
#             sentiment += int(sentiword_dic.polarity[i])  # 감성단어가 있다면 극성값 합계를 구함
#     df.loc[idx] = [adj_verb, sentiment]  # 리뷰별 극성값을 데이터프레임으로 쌓음
#     idx += 1  # 다음 리뷰 문장으로 넘어감

# %%
df = pd.DataFrame(columns=('review', '시설분류', 'adj_verb_stemmed', 'sentiment', 'label'))
idx = 0 # 다음 리뷰로 넘기기 위한 초기값

for idx, row in df_review_data.iloc[:20].iterrows():  # 처음 20개의 행에 대해 루프
    review = row['review']  # 리뷰 가져오기
    시설분류 = row['시설분류']  # 시설분류 가져오기
    adj_verb_stemmed = row['adj_verb_stemmed']  # adj_verb 가져오기
    sentiment = 0  # 초기 감성값 0으로 설정
    for i in range(len(sentiword_dic)):  # 감성사전의 모든 단어에 대해 루프
        if sentiword_dic.word_root[i] in adj_verb_stemmed and sentiword_dic.word[i] in adj_verb_stemmed:  # 리뷰 문장에 감성 단어가 있는지 확인
            sentiment += int(sentiword_dic.polarity[i])  # 감성단어가 있다면 극성값 합계를 구함
    label = 1 if sentiment >= 0 else 0  # sentiment 값에 따라 label 값 할당
    df.loc[idx] = [review, 시설분류, adj_verb_stemmed, sentiment, label]  # 리뷰별 극성값과 label을 데이터프레임으로 쌓음

# %%
df
# Out:
#                                                review 시설분류  \
# 0                                                친절해요   문화
# 1                                          좋아요 만족스러워요   문화
# 2                                                 좋아요   문화
# 3                                                 좋아요   문화
# 4                  휴일날 찾아간 각화제~\n가을을 부르는 꽃이 피어있네요 ㅋㅋ    문화
# 5                                            산책하기 좋아요   문화
# 6          처음 가봤는데 산책로가 잘 되어있네요~\n한적하게 산책하며 힐링하기 좋습니다   문화
# 7   보현사에서 시작~구릉산~갈매구릉산자락길~모다아울렛구리.갈매역까지 걷기\n\n갈매역 ...   문화
# 8                                                좋습니다   문화
# 9                                                 좋아요   문화
# 10                                                좋아요   문화
# 11  포근한 봄날씨에 강아지와 강아지 숲에서  즐거운 시간을 보내고 왔어요🌸 봄바람 살랑...   문화
# 12  산책+오프리쉬 놀이터 위주라면 봄, 가을 수영장 위주라면 여름 추천합니다! 공간이 ...   문화
# 13  강아지 성지가 될 최고의 장소 - 우연하게 찾아서 예약하고 갔는데 한국 사는 강아지...   문화
# 14  국제강아지의날을 맞이해서 반려견 다찌와 함께 다녀왔어요! 중소형견과 대형견를 위한 ...   문화
# 15  야자매트가 깔려 있는  산책로를  강아지가  너무 좋아해요. 강아지가 길을 따라 냄...   문화
# 16  날씨가 꽤 추울때 방문했는데 강아지들이 꽤 있더라구요. 시설도 깔끔하고 안에 잔디밭...   문화
# 17  입장해서 강아지 운동장,그리고 산책길,마지막은 강아지 박물관도 다녀오느라 거의 3시...   문화
# 18  바람불고 쌀쌀했지만 초코한테는 딱 좋은 날씨라서 먼길 나섰죠 방문객 적어서 전용공간...   문화
# 19  예전부터 정말 가고싶었던 강아지숲! 기대하고 방문했는데, 기대를 너무 많이 했나봐요...   문화
#
#                                      adj_verb_stemmed  sentiment  label
# 0                                                친절하다          4      1
# 1                                            좋다 만족스럽다          6      1
# 2                                                  좋다          2      1
# 3                                                  좋다          2      1
# 4                                         찾아가다 부르다 피다          0      1
# 5                                               하다 좋다          2      1
# 6                            가보다 자다 되어다 한적하다 하다 하다 좋다          2      1
# 7                                      있다 하다 좋다 있다 좋다          2      1
# 8                                                  좋다          2      1
# 9                                                  좋다          2      1
# 10                                                 좋다          2      1
# 11              포근하다 즐겁다 보내다 오다 불다 걷다 먹다 쉬다 있다 좋다 예쁘다          8      1
# 12  하다 크다 그렇다 보다 같다 나눠지다 있다 좋다 사악하다 있다 쓸다 되다 같다 있다...          0      1
# 13  되다 하다 찾다 가다 살다 어울리다 좋다 이다 기르다 안되다 충분하다 쌓다 있다 하...          8      1
# 14      하다 다녀오다 있다 같다 적당하다 좋다 맛있다 되어다 만족스럽다 오다 이다 의하다          8      1
# 15  깔다 있다 좋아하다 따르다 맡다 올라가다 사먹다 말다 쉬다 있다 맛있다 깨끗하다 놓...         10      1
# 16  추다 하다 있다 깔끔하다 되어다 넓다 대다 편하다 있다 하다 편하다 하다 걸다 충분...          3      1
# 17           하다 다녀오다 보내다 같다 하다 많다 느껴지다 좋다 하다 있다 좋다 이다          3      1
# 18     쌀쌀하다 늘다 좋다 멀다 나서다 적다 신나다 놀다 편하다 먹다 좋다 더워지다 가보다          6      1
# 19  가다 기대하다 하다 하다 보다 크다 같다 오다 걸리다 만들다 놀라다 맛있다 차다 아...          2      1

# %%
# df = pd.DataFrame(columns=('review', '시설분류', 'adj_verb_stemmed', 'sentiment', 'label'))
# idx = 0 # 다음 리뷰로 넘기기 위한 초기값

# for idx, row in df_review_data.iterrows():  # 처음 20개의 행에 대해 루프
#     review = row['review']  # 리뷰 가져오기
#     시설분류 = row['시설분류']  # 시설분류 가져오기
#     adj_verb = row['adj_verb_stemmed']  # adj_verb 가져오기
#     sentiment = 0  # 초기 감성값 0으로 설정
#     for i in range(len(sentiword_dic)):  # 감성사전의 모든 단어에 대해 루프
#         if sentiword_dic.word_root[i] in adj_verb and sentiword_dic.word[i] in adj_verb:  # 리뷰 문장에 감성 단어가 있는지 확인
#             sentiment += int(sentiword_dic.polarity[i])  # 감성단어가 있다면 극성값 합계를 구함
#     label = 1 if sentiment >= 0 else 0  # sentiment 값에 따라 label 값 할당
#     df.loc[idx] = [review, 시설분류, adj_verb, sentiment, label]  # 리뷰별 극성값과 label을 데이터프레임으로 쌓음

# %%
df = pd.DataFrame(columns=('review', '시설분류', 'adj_verb_stemmed', 'sentiment', 'label'))
idx = 0 # 다음 리뷰로 넘기기 위한 초기값

for idx, row in tqdm(df_review_data.iterrows(), total=len(df_review_data)): 
    review = row['review']  # 리뷰 가져오기
    시설분류 = row['시설분류']  # 시설분류 가져오기
    adj_verb_stemmed = row['adj_verb_stemmed']  # adj_verb 가져오기
    sentiment = 0  # 초기 감성값 0으로 설정
    for i in range(len(sentiword_dic)):  # 감성사전의 모든 단어에 대해 루프
        if sentiword_dic.word_root[i] in adj_verb_stemmed and sentiword_dic.word[i] in adj_verb_stemmed:  # 리뷰 문장에 감성 단어가 있는지 확인
            sentiment += int(sentiword_dic.polarity[i])  # 감성단어가 있다면 극성값 합계를 구함
    label = 1 if sentiment >= 0 else 0  # sentiment 값에 따라 label 값 할당
    df.loc[idx] = [review, 시설분류, adj_verb_stemmed, sentiment, label]  # 리뷰별 극성값과 label을 데이터프레임으로 쌓음
# Out:
#  15%|███████████▎                                                             | 17045/110386 [33:49<3:34:53,  7.24it/s]

# %%
df
# Out:
#                                                review 시설분류  \
# 0                                [[친], [절], [해], [요]]   문화
# 1   [[좋다], [아], [요], [], [만], [족], [스], [러], [워], ...   문화
# 2                                    [[좋다], [아], [요]]   문화
# 3                                    [[좋다], [아], [요]]   문화
# 4   [[찾다], [아], [간], [], [부], [르], [늘다], [], [피], ...   문화
# 5                      [[하], [기], [], [좋다], [아], [요]]   문화
# 6   [[가다], [보다], [늘다], [데], [], [자다], [], [되다], [어...   문화
# 7   [[있다], [어], [], [하], [기], [], [좋다], [음], [], [...   문화
# 8                               [[좋다], [습], [니], [다]]   문화
# 9                                    [[좋다], [아], [요]]   문화
# 10                                   [[좋다], [아], [요]]   문화
# 11  [[포], [근], [하다], [], [즐], [거], [운], [], [보], [...   문화
# 12  [[합], [니], [다], [], [크다], [고], [], [그], [런], [...   문화
# 13  [[되다], [], [하], [게], [], [찾다], [아], [서다], [], ...   문화
# 14  [[해], [서다], [], [다], [녀], [오다], [어], [요], [], ...   문화
# 15  [[깔다], [려], [], [있다], [늘다], [], [좋다], [아], [해]...   문화
# 16  [[추], [울], [], [하다], [늘다], [데], [], [있다], [더],...   문화
# 17  [[해], [서다], [], [다], [녀], [오], [느], [라], [], [...   문화
# 18  [[쌀], [쌀], [하다], [지다], [만], [], [늘다], [], [좋다]...   문화
# 19  [[가다], [고], [싶다], [었], [던], [], [기], [대다], [하]...   문화
#
#                                              adj_verb  sentiment  label
# 0                                                친절해요          0      1
# 1                                          좋아요 만족스러워요          4      1
# 2                                                 좋아요          2      1
# 3                                                 좋아요          2      1
# 4                                       찾아간 부르는 피어있네요          0      1
# 5                                              하기 좋아요          2      1
# 6                        가봤는데 잘 되어있네요 한적하게 하며 하기 좋습니다          0      1
# 7                                      있어 하기 좋음 있어 좋음          2      1
# 8                                                좋습니다          0      1
# 9                                                 좋아요          2      1
# 10                                                좋아요          2      1
# 11          포근한 즐거운 보내고 왔어요 부는 걷고 먹으며 쉴수 있어서 좋아요 예뻤어요          4      1
# 12  합니다 크고 그런지 본 같아요 나눠져 있어서 좋았어요 사악하긴 있네요 쓸 될 같아요...          2      1
# 13  될 하게 찾아서 갔는데 사는 어울리기 좋은 입니다 기라 안되지만 충분히 쌓을 있는 ...          6      1
# 14  해서 다녀왔어요 있어서 같은 적당하고 좋았어요 맛있고 되어있어서 만족스러웠습니다 와...          0      1
# 15  깔려 있는 좋아해요 따라 맡으며 올라가면 사먹으며 마시고 쉴수 있어요 맛있구요 깨끗...          6      1
# 16  추울 했는데 있더라구요 깔끔하고 되어있었어요 넓어서 댈 편하고 있어서 하기 편한듯 ...          5      1
# 17   해서 다녀오느라 보낸것 같아요 할것도 많고 느껴졌어요 좋을 할 있습니다 좋은 이었습니다          2      1
# 18  쌀쌀했지만 는 좋은 먼길 나섰죠 적어서 신나게 놀고 편하게 먹고 좋았어요 더워지기 ...          4      1
# 19  가고싶었던 기대하고 했는데 했나 봐요 큰 같다고 왔어요 걸리네요 만들어주셔서 놀랐어...          1      1

# %%
from tqdm import tqdm

# tqdm에 대한 pandas의 apply 함수를 활성화합니다.
tqdm.pandas()

# %%
# 감정 점수 계산 함수
def calculate_sentiment(row):
    sentiment = 0
    for _, dic_row in sentiword_dic.iterrows():
        if dic_row['word_root'] == row['adj_verb_stemmed'] and dic_row['word'] == row['adj_verb_stemmed']:
            sentiment += dic_row['polarity']
            break
    return sentiment

# %%
# 감정 점수 및 레이블 계산 (tqdm을 사용하여 진행률을 표시합니다.)
df_review_data['sentiment'] = df_review_data.progress_apply(calculate_sentiment, axis=1)
df_review_data['label'] = df_review_data['sentiment'].apply(lambda x: 'positive' if x > 0 else ('neutral' if x == 0 else 'negative'))

# 최종 DataFrame 준비
df = df_review_data[['review', 'facility_type', 'adj_verb_stemmed', 'sentiment', 'label']]
# Out:
#   4%|██▌                                                                      | 3968/110386 [53:21<23:51:09,  1.24it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 2
#       1 # 감정 점수 및 레이블 계산 (tqdm을 사용하여 진행률을 표시합니다.)
# ----> 2 df_review_data['sentiment'] = df_review_data.progress_apply(calculate_sentiment, axis=1)
#       3 df_review_data['label'] = df_review_data['sentiment'].apply(lambda x: 'positive' if x > 0 else ('neutral' if x == 0 else 'negative'))
#       5 # 최종 DataFrame 준비
#
# File D:\kdit\anaconda3\Lib\site-packages\tqdm\std.py:805, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     802 # Apply the provided function (in **kwargs)
#     803 # on the df using our wrapper (which provides bar updating)
#     804 try:
# --> 805     return getattr(df, df_function)(wrapper, **kwargs)
#     806 finally:
#     807     t.close()
#
# File D:\kdit\anaconda3\Lib\site-packages\pandas\core\frame.py:9423, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9412 from pandas.core.apply import frame_apply
#    9414 op = frame_apply(
#    9415     self,
#    9416     func=func,
#    (...)
#    9421     kwargs=kwargs,
#    9422 )
# -> 9423 return op.apply().__finalize__(self, method="apply")
#
# File D:\kdit\anaconda3\Lib\site-packages\pandas\core\apply.py:678, in FrameApply.apply(self)
#     675 elif self.raw:
#     676     return self.apply_raw()
# --> 678 return self.apply_standard()
#
# File D:\kdit\anaconda3\Lib\site-packages\pandas\core\apply.py:798, in FrameApply.apply_standard(self)
#     797 def apply_standard(self):
# --> 798     results, res_index = self.apply_series_generator()
#     800     # wrap results
#     801     return self.wrap_results(results, res_index)
#
# File D:\kdit\anaconda3\Lib\site-packages\pandas\core\apply.py:814, in FrameApply.apply_series_generator(self)
#     811 with option_context("mode.chained_assignment", None):
#     812     for i, v in enumerate(series_gen):
#     813         # ignore SettingWithCopy here in case the user mutates
# --> 814         results[i] = self.f(v)
#     815         if isinstance(results[i], ABCSeries):
#     816             # If we have a view on v, we need to make a copy because
#     817             #  series_generator will swap out the underlying data
#     818             results[i] = results[i].copy(deep=False)
#
# File D:\kdit\anaconda3\Lib\site-packages\tqdm\std.py:800, in tqdm.pandas.<locals>.inner_generator.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     794 def wrapper(*args, **kwargs):
#     795     # update tbar correctly
#     796     # it seems `pandas apply` calls `func` twice
#     797     # on the first column/row to decide whether it can
#     798     # take a fast or slow code path; so stop when t.total==t.n
#     799     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 800     return func(*args, **kwargs)
#
# Cell In[26], line 4, in calculate_sentiment(row)
#       2 def calculate_sentiment(row):
#       3     sentiment = 0
# ----> 4     for _, dic_row in sentiword_dic.iterrows():
#       5         if dic_row['word_root'] == row['adj_verb_stemmed'] and dic_row['word'] == row['adj_verb_stemmed']:
#       6             sentiment += dic_row['polarity']
#
# File D:\kdit\anaconda3\Lib\site-packages\pandas\core\frame.py:1400, in DataFrame.iterrows(self)
#    1398 using_cow = using_copy_on_write()
#    1399 for k, v in zip(self.index, self.values):
# -> 1400     s = klass(v, index=columns, name=k).__finalize__(self)
#    1401     if using_cow and self._mgr.is_single_block:
#    1402         s._mgr.add_references(self._mgr)  # type: ignore[arg-type]
#
# File D:\kdit\anaconda3\Lib\site-packages\pandas\core\series.py:513, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     511 manager = get_option("mode.data_manager")
#     512 if manager == "block":
# --> 513     data = SingleBlockManager.from_array(data, index, refs=refs)
#     514 elif manager == "array":
#     515     data = SingleArrayManager.from_array(data, index)
#
# File D:\kdit\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1880, in SingleBlockManager.from_array(cls, array, index, refs)
#    1873 @classmethod
#    1874 def from_array(
#    1875     cls, array: ArrayLike, index: Index, refs: BlockValuesRefs | None = None
#    1876 ) -> SingleBlockManager:
#    1877     """
#    1878     Constructor for if we have an array that is not yet a Block.
#    1879     """
# -> 1880     block = new_block(array, placement=slice(0, len(index)), ndim=1, refs=refs)
#    1881     return cls(block, index)
#
# File D:\kdit\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:2397, in new_block(values, placement, ndim, refs)
#    2393 check_ndim(values, placement, ndim)
#    2395 klass = get_block_type(values.dtype)
# -> 2397 values = maybe_coerce_values(values)
#    2398 return klass(values, ndim=ndim, placement=placement, refs=refs)
#
# File D:\kdit\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:2322, in maybe_coerce_values(values)
#    2319 # Caller is responsible for ensuring PandasArray is already extracted.
#    2321 if isinstance(values, np.ndarray):
# -> 2322     values = ensure_wrapped_if_datetimelike(values)
#    2324     if issubclass(values.dtype.type, str):
#    2325         values = np.array(values, dtype=object)
#
# File D:\kdit\anaconda3\Lib\site-packages\pandas\core\construction.py:458, in ensure_wrapped_if_datetimelike(arr)
#     453         return obj.to_numpy()
#     455     return obj
# --> 458 def ensure_wrapped_if_datetimelike(arr):
#     459     """
#     460     Wrap datetime64 and timedelta64 ndarrays in DatetimeArray/TimedeltaArray.
#     461     """
#     462     if isinstance(arr, np.ndarray):
#
# KeyboardInterrupt:

# %%
df.to_csv('data/knu_data_review_test2.csv', index=False, encoding='utf-8-sig')
