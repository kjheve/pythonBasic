# %%
import json
import pandas as pd

# %%
with open('data/SentiWord_info.json', encoding='utf-8-sig', mode='r') as f:
    Sentiword_info = json.load(f)

# %%
sentiword_dic = pd.DataFrame(Sentiword_info)

# %%
sentiword_dic
# Out:
#          word word_root polarity
# 0         (-;         (        1
# 1       (;_;)     (;_;)       -1
# 2        (^^)      (^^)        1
# 3       (^-^)     (^-^)        1
# 4        (^^*         (        1
# ...       ...       ...      ...
# 14849  반신반의하다      반신반의        0
# 14850    신비롭다        신비        1
# 14851   아리송하다       아리송       -1
# 14852    알쏭하다       알쏭하       -1
# 14853  알쏭달쏭하다      알쏭달쏭       -1
#
# [14854 rows x 3 columns]

# %%
df_2t = pd.read_csv('data/test.csv', encoding='utf-8')

# %%
df_2t.head()
# Out:
#        review label     review2         adj verb noun exclamation    adj_norm  \
# 0           ?    문화         NaN         NaN  NaN  NaN         NaN         NaN
# 1        친절해요    문화        친절해요        친절해요  NaN  NaN         NaN        친절해요
# 2  좋아요 만족스러워요    문화  좋아요 만족스러워요  좋아요 만족스러워요  NaN  NaN         NaN  좋아요 만족스러워요
# 3        와우~~    문화          와우         NaN  NaN   와우         NaN         NaN
# 4           굿    문화           굿         NaN  NaN    굿         NaN         NaN
#
#           adj_stem
# 0          ['nan']
# 1         ['친절하다']
# 2  ['좋다', '만족스럽다']
# 3          ['nan']
# 4          ['nan']

# %%
df_2t.isnull().sum()
# Out:
# review              0
# label               0
# review2          4488
# adj             39911
# verb            81275
# noun            47397
# exclamation    140042
# adj_norm        39911
# adj_stem            0
# dtype: int64

# %%
df = pd.DataFrame(columns=('review', 'sentiment'))
idx = 0 # 다음 리뷰로 넘기기 위한 초기값
for token in df_2t['adj_stem']:                    # df_2t['adj_stem']의 각 토큰에 대해 루프를 돕니다.
    sentiment = 0                                  # 초기 감성값 0으로 설정
    for i in range(0, len(sentiword_dic)):         # 감성사전의 모든 단어를 하나씩 선택
        if sentiword_dic.word[i] in token:         # 리뷰 문장에 감성 단어가 있는지 확인
            sentiment += int(sentiword_dic.polarity[i])  # 감성단어가 있다면 극성값 합계를 구함.
    df.loc[idx] = [token, sentiment]               # 리뷰별 극성값을 데이터프레임으로 쌓음
    idx += 1                                       # 다음 리뷰 문장으로 넘어감
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 6
#       4 sentiment = 0                                  # 초기 감성값 0으로 설정
#       5 for i in range(0, len(sentiword_dic)):         # 감성사전의 모든 단어를 하나씩 선택
# ----> 6     if sentiword_dic.word[i] in token:         # 리뷰 문장에 감성 단어가 있는지 확인
#       7         sentiment += int(sentiword_dic.polarity[i])  # 감성단어가 있다면 극성값 합계를 구함.
#       8 df.loc[idx] = [token, sentiment]               # 리뷰별 극성값을 데이터프레임으로 쌓음
#
# File D:\kdit\anaconda3\Lib\site-packages\pandas\core\generic.py:5988, in NDFrame.__getattr__(self, name)
#    5980 # Note: obj.x will always call obj.__getattribute__('x') prior to
#    5981 # calling obj.__getattr__('x').
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
# -> 5988     return self[name]
#    5989 return object.__getattribute__(self, name)
#
# File D:\kdit\anaconda3\Lib\site-packages\pandas\core\frame.py:3718, in DataFrame.__getitem__(self, key)
#    3715 key = lib.item_from_zerodim(key)
#    3716 key = com.apply_if_callable(key, self)
# -> 3718 if is_hashable(key) and not is_iterator(key):
#    3719     # is_iterator to exclude generator e.g. test_getitem_listlike
#    3720     # shortcut if the key is in columns
#    3721     is_mi = isinstance(self.columns, MultiIndex)
#    3722     # GH#45316 Return view if key is not duplicated
#    3723     # Only use drop_duplicates with duplicates for performance
#
# File D:\kdit\anaconda3\Lib\site-packages\pandas\core\dtypes\inference.py:360, in is_hashable(obj)
#     352 # Unfortunately, we can't use isinstance(obj, collections.abc.Hashable),
#     353 # which can be faster than calling hash. That is because numpy scalars
#     354 # fail this test.
#     355
#     356 # Reconsider this decision once this numpy bug is fixed:
#     357 # https://github.com/numpy/numpy/issues/5562
#     359 try:
# --> 360     hash(obj)
#     361 except TypeError:
#     362     return False
#
# KeyboardInterrupt:

# %%
df
# Out:
#                       review  sentiment
# 0                    ['nan']          0
# 1                   ['친절하다']          4
# 2            ['좋다', '만족스럽다']          6
# 3                    ['nan']          0
# 4                    ['nan']          0
# 5                    ['nan']          0
# 6                     ['좋다']          2
# 7                    ['nan']          0
# 8                     ['좋다']          2
# 9                    ['nan']          0
# 10                   ['nan']          0
# 11                   ['nan']          0
# 12                    ['좋다']          2
# 13            ['한적하다', '좋다']          2
# 14                   ['nan']          0
# 15                   ['nan']          0
# 16  ['있다', '좋다', '있다', '좋다']          2
# 17                    ['좋다']          2
# 18                   ['nan']          0
# 19                   ['nan']          0

# %%
df.to_csv('data/test_2.csv', index=False, encoding='utf-8-sig')
